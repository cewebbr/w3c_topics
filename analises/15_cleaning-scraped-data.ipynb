# %% [markdown]
# # Cleaning and exploring data

# %%
import pandas as pd
from glob import glob

import xavy.explore as xe
import xavy.dataframes as xd

# %% [markdown]
# ## Load data

# %%
filenames = glob('../dados/brutos/w3c-wg-members_*.csv')
raw_members_df = pd.concat([pd.read_csv(f) for f in filenames])

# %% [markdown]
# ## Explore raw data

# %% [markdown]
# **Findings**
# 1. Organization name and URL are biunivocal
# 2. The only organization with no URL is W3C or its invited experts
# 3. There are people affiliated to different organizations
# 4. Invited experts may come from companies
# 5. E-mails identify people, but people can have more than one email:
#     1. All members have a listed email.
#     2. Ignoring people with no picture, all pictures are biunivocal to emails
#     3. There are no emails with more than one name associated to it.
#     4. **There are people with more than one email**

# %% [markdown]
# ### Basic stuff

# %%
xe.checkMissing(raw_members_df)
# Out:
# Colunas com valores faltantes:
#     coluna       N      %
# 2  org_url   406.0  14.69
# 4   github  1029.0  37.24

# %%
xe.mapUnique(raw_members_df)
# Out:
# name: 1851 unique values.
# (sample) Airing Deng,  Alex Turner,  Andy Wingo,  Anthony Joseph Castillo,  Ashwin Balasubramaniyan,  Etienne Segonzac,  Ganesh Annan,  Jacob Rossi,  Jeff Owenson,  Jer Noble,  Keith Winstein,  Leigh Garner,  Marcos Caceres,  Masato Ito,  Max Hata,  Philip Eliasson,  Philipp-Alexander Blum,  Roderick Sheeter,  Rolf Lindemann,  Tiffany Burtin
#
# org_name: 230 unique values.
# (sample) ACCESS CO., LTD.,  Amazon,  AudioEye, Inc.,  Defense Information Systems Agency,  Entersekt,  Fastly,  Fondazione LIA,  Fraunhofer Gesellschaft,  J. Paul Getty Trust,  Mavennet Systems Inc.,  Natural Resources Canada,  OpenLink Software Inc.,  Protocol Labs,  Samsung Electronics Co., Ltd.,  Snake Nation,  Stanford University,  The New York Times,  Thomson Reuters Corp.,  Tigim,  UnitedHealth Group
#
# org_url: 229 unique values.
# (sample) https://www.w3.org/organizations/10911/,  https://www.w3.org/organizations/112585/,  https://www.w3.org/organizations/1142/,  https://www.w3.org/organizations/116443/,  https://www.w3.org/organizations/117162/,  https://www.w3.org/organizations/117787/,  https://www.w3.org/organizations/126165/,  https://www.w3.org/organizations/126211/,  https://www.w3.org/organizations/152991/,  https://www.w3.org/organizations/34345/,  https://www.w3.org/organizations/36231/,  https://www.w3.org/organizations/36700/,  https://www.w3.org/organizations/38525/,  https://www.w3.org/organizations/38621/,  https://www.w3.org/organizations/39381/,  https://www.w3.org/organizations/48275/,  https://www.w3.org/organizations/56271/,  https://www.w3.org/organizations/62028/,  https://www.w3.org/organizations/70179/,  https://www.w3.org/organizations/98847/
#
# email: 1858 unique values.
# (sample) bnordman@lbl.gov,  chris.seeger@nbcuni.com,  chus.garcia@fundacionctic.org,  clinton.r.allen@aexp.com,  david.trang@uac.edu.au,  duerst@it.aoyama.ac.jp,  ikilpatrick@google.com,  kris.ketels@swift.com,  kzaky@amazon.com,  mprorock@mesur.io,  nashley@google.com,  philipp-blum@desertmonitor.com,  romainmenke@gmail.com,  sblackmon@apache.org,  smajali@nvidia.com,  souripriya.das@oracle.com,  srikanth.kambhatla@intel.com,  sten@ver.id,  tsnyder@gs1us.org,  youenn@apple.com
#
# github: 1056 unique values.
# (sample) https://github.com/DavMila,  https://github.com/anatoly-scherbakov,  https://github.com/avneeshsingh,  https://github.com/baszoetekouw,  https://github.com/bkardell,  https://github.com/camillelamy,  https://github.com/dan-hw,  https://github.com/ddworken,  https://github.com/dr-sudo,  https://github.com/ebremer,  https://github.com/fordacious,  https://github.com/gobengo,  https://github.com/hidde,  https://github.com/humeranoor,  https://github.com/martyr280,  https://github.com/mikewest,  https://github.com/nhelfman,  https://github.com/racheleditullio,  https://github.com/steveanton,  https://github.com/wilaw
#
# picture: 801 unique values.
# (sample) https://www.w3.org/thumbnails/100/avatar-images/1fjwtql0z41wg48goowsg88s800gsw8.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/397jq06a10ysgcsokssok0ww4s0osgk.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/3sxyf6xr7yyo4ook8oc48sww8ggo8g8.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/7fvzlzd41fggsgckg0sggowcgsw0kgk.webp?x-version=2,  https://www.w3.org/thumbnails/100/avatar-images/8xbaonnh2g4kogk8w8w8ocs0ckw84c4.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/9aprba3xya88c4kwggks84skk0skc4k.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/a67xbhslnqgoogckwsk48wgo4cg84k4.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/az7lzx8gyigw440oo0s4kcco0ww4wko.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/bi9m9m8pttwkk808g0w4cwwc4so8gcw.webp?x-version=2,  https://www.w3.org/thumbnails/100/avatar-images/eowv1ng9btsgsoosgo44cs88s4840og.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/fe54j5loox4o4ooo04gw8s0wgkg044s.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/i80p5bskshwgggwgks84kgoggsc8ko0.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/ilhlblrre9s0008w00gog4soo8scwws.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/j4olzni8mmo8s8804go0osgo8k0sg4o.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/mjmlptdvqz4cgccksosw4gok4oowckk.webp?x-version=2,  https://www.w3.org/thumbnails/100/avatar-images/n43mlczz7bkcccsc0840oo8so4o40sk.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/o3he85ts0z4s48c4c0wwk04kkcog44o.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/s460v84tnsgoswskc8owwks0kwwg0gw.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/s5qsla39msggw4occg484g0o04sk4kw.webp?x-version=1,  https://www.w3.org/thumbnails/100/avatar-images/tkgxmc97wpw448k844kwwogsk0cwckw.webp?x-version=1
#
# role: 3 unique values.
# chairs,  participants,  staff
#
# group_tag: 43 unique values.
# (sample) ag,  aria,  css,  das,  did,  distributed-tracing,  fedid,  gpu,  i18n-core,  json-ld,  math,  media,  rch,  sdw,  secondscreen,  timed-text,  webapps,  webappsec,  webfonts,  webmachinelearning

# %% [markdown]
# ### Sanity checks

# %% [markdown]
# #### Organization URL

# %%
xe.one2oneViolations(raw_members_df, 'org_name', 'org_url')
# Out:
# Series([], Name: org_url, dtype: object)

# %%
xe.one2oneViolations(raw_members_df, 'org_url', 'org_name')
# Out:
# Series([], Name: org_name, dtype: object)

# %%
raw_members_df.loc[raw_members_df['org_url'].isnull(), 'org_name'].value_counts()
# Out:
# org_name
# W3C Invited Experts    288
# W3C                    118
# Name: count, dtype: int64

# %% [markdown]
# #### Picture

# %%
picture_df = raw_members_df.loc[raw_members_df['picture'] != 'https://www.w3.org/assets/website-2021/svg/avatar.svg']

# %%
xe.one2oneQ(picture_df, 'email', 'picture')
# Out:
# True

# %% [markdown]
# #### Email

# %%
xd.print_array_series(xe.one2oneViolations(raw_members_df, 'name', 'email'))
# Out:
# Benjamin Poulain: bpoulain@apple.com / benjamin@webkit.org
# Hidde de Vries: hidde-logius@hiddedevries.nl / hidde@hiddedevries.nl
# Jan Williams: jwilliams@paciellogroup.com / jwilliams@tpgi.com
# Jim Evans: james.h.evans.jr@gmail.com / james.evans@salesforce.com
# Lei Zhao: zhaolei@migu.cn / zhaolei07@baidu.com
# Michael Jones: michael_b_jones@hotmail.com / michael.jones@mattr.global
# Thomas Nguyen: tungnh@google.com / tomnguyen@google.com

# %%
xe.one2oneViolations(raw_members_df, 'email', 'name')
# Out:
# Series([], Name: name, dtype: object)

# %% [markdown]
# #### Affiliation

# %%
xd.print_array_series(xe.one2oneViolations(raw_members_df, 'name', 'org_name'))
# Out:
# Hidde de Vries: Logius / W3C Invited Experts
# Jim Evans: W3C Invited Experts / Salesforce
# Lei Zhao: China Mobile Communications Corporation / Baidu, Inc.
# Michael Jones: W3C Invited Experts / Mattr Limited

# %%
raw_members_df
# Out:
#                    name                                     org_name  \
# 0         Daniel Veditz                           Mozilla Foundation
# 1             Mike West                                   Google LLC
# 2   Philippe Le Hegaret                                          W3C
# 3         Simone Onofri                                          W3C
# 4          David Adrian                                   Google LLC
# ..                  ...                                          ...
# 93        Valerie Young                                       Igalia
# 94            Kate Zhao                        Thomson Reuters Corp.
# 95    Xiao (Helen) Zhou                       University of Illinois
# 96        Filippo Zorzi                                    UsableNet
# 97                  骅 杨  Shenzhen Accessibility Research Association
#
#                                      org_url                         email  \
# 0    https://www.w3.org/organizations/35507/           dveditz@mozilla.com
# 1    https://www.w3.org/organizations/35662/              mkwst@google.com
# 2                                        NaN                    plh@w3.org
# 3                                        NaN                 simone@w3.org
# 4    https://www.w3.org/organizations/35662/            dadrian@google.com
# ..                                       ...                           ...
# 93   https://www.w3.org/organizations/62028/        spectranaut@igalia.com
# 94  https://www.w3.org/organizations/111458/  kate.zhao@thomsonreuters.com
# 95   https://www.w3.org/organizations/51381/           xhzhou@illinois.edu
# 96  https://www.w3.org/organizations/138132/   filippo.zorzi@usablenet.com
# 97  https://www.w3.org/organizations/129545/           yanghua@siaa.org.cn
#
#                               github  \
# 0         https://github.com/dveditz
# 1        https://github.com/mikewest
# 2        https://github.com/plehegar
# 3    https://github.com/simoneonofri
# 4         https://github.com/dadrian
# ..                               ...
# 93    https://github.com/spectranaut
# 94     https://github.com/KateZhaoTR
# 95    https://github.com/helen-libit
# 96  https://github.com/filippo-zorzi
# 97                               NaN
#
#                                               picture          role  group_tag
# 0   https://www.w3.org/thumbnails/100/avatar-image...        chairs  webappsec
# 1   https://www.w3.org/thumbnails/100/avatar-image...        chairs  webappsec
# 2   https://www.w3.org/thumbnails/100/avatar-image...         staff  webappsec
# 3   https://www.w3.org/thumbnails/100/avatar-image...         staff  webappsec
# 4   https://www.w3.org/assets/website-2021/svg/ava...  participants  webappsec
# ..                                                ...           ...        ...
# 93  https://www.w3.org/assets/website-2021/svg/ava...  participants       aria
# 94  https://www.w3.org/assets/website-2021/svg/ava...  participants       aria
# 95  https://www.w3.org/thumbnails/100/avatar-image...  participants       aria
# 96  https://www.w3.org/assets/website-2021/svg/ava...  participants       aria
# 97  https://www.w3.org/assets/website-2021/svg/ava...  participants       aria
#
# [2763 rows x 8 columns]

# %%
raw_members_df.query('role != "staff"')['org_name'].value_counts(normalize=True).head(20)
# Out:
# org_name
# Google LLC                          0.150756
# W3C Invited Experts                 0.106156
# Microsoft Corporation               0.063030
# Apple Inc.                          0.053446
# Intel Corporation                   0.028013
# Mozilla Foundation                  0.026539
# W3C                                 0.025065
# ByteDance                           0.018430
# Igalia                              0.016587
# Meta                                0.015481
# Adobe                               0.011795
# TPGi                                0.010321
# Digital Bazaar                      0.010321
# Samsung Electronics Co., Ltd.       0.009583
# TetraLogical Services Ltd           0.008846
# British Broadcasting Corporation    0.007741
# Alibaba Group                       0.007741
# Rakuten Group, Inc.                 0.007372
# Baidu, Inc.                         0.007372
# Entersekt                           0.007003
# Name: proportion, dtype: float64

# %%
raw_members_df.query('role == "chairs"')['org_name'].value_counts(normalize=True).head(20)
# Out:
# org_name
# W3C Invited Experts                 0.205128
# Google LLC                          0.115385
# Mozilla Foundation                  0.051282
# Intel Corporation                   0.051282
# Microsoft Corporation               0.038462
# Adobe                               0.038462
# British Broadcasting Corporation    0.038462
# TetraLogical Services Ltd           0.038462
# Apple Inc.                          0.038462
# Igalia                              0.025641
# Akamai Technologies                 0.025641
# TPGi                                0.012821
# Samsung Electronics Co., Ltd.       0.012821
# Shopify                             0.012821
# Geonovum                            0.012821
# Spherical Cow Consulting            0.012821
# Baidu, Inc.                         0.012821
# Alibaba Group                       0.012821
# Huawei                              0.012821
# Fastly                              0.012821
# Name: proportion, dtype: float64

# %% [markdown]
# # Trash

# %%
groups_df = pd.read_csv('../dados/brutos/w3c_wg_2024-07-04.csv')

# %%
groups_df
# Out:
#                                                  name  \
# 0   Accessibility Education and Outreach Working G...
# 1              Accessibility Guidelines Working Group
# 2     Accessible Platform Architectures Working Group
# 3   Accessible Rich Internet Applications Working ...
# 4                                 Audio Working Group
# 5             Browser Testing and Tools Working Group
# 6          Cascading Style Sheets (CSS) Working Group
# 7                      Dataset Exchange Working Group
# 8              Decentralized Identifier Working Group
# 9                   Devices and Sensors Working Group
# 10                  Distributed Tracing Working Group
# 11                   Federated Identity Working Group
# 12                      GPU for the Web Working Group
# 13                                 HTML Working Group
# 14                        Immersive Web Working Group
# 15                 Internationalization Working Group
# 16                              JSON-LD Working Group
# 17                                 Math Working Group
# 18                                Media Working Group
# 19                             MiniApps Working Group
# 20                       Pointer Events Working Group
# 21      Portable Network Graphics (PNG) Working Group
# 22               Publishing Maintenance Working Group
# 23  RDF Dataset Canonicalization and Hash Working ...
# 24                             RDF-star Working Group
# 25                        Second Screen Working Group
# 26                      Service Workers Working Group
# 27              Spatial Data on the Web Working Group
# 28                                  SVG Working Group
# 29                           Timed Text Working Group
# 30               Verifiable Credentials Working Group
# 31             Web Application Security Working Group
# 32                     Web Applications Working Group
# 33                   Web Authentication Working Group
# 34                          Web Editing Working Group
# 35                            Web Fonts Working Group
# 36                 Web Machine Learning Working Group
# 37                        Web of Things Working Group
# 38                         Web Payments Working Group
# 39                      Web Performance Working Group
# 40         Web Real-Time Communications Working Group
# 41                          WebAssembly Working Group
# 42                         WebTransport Working Group
#
#                                                   url  \
# 0                  https://www.w3.org/groups/wg/eowg/
# 1                    https://www.w3.org/groups/wg/ag/
# 2                   https://www.w3.org/groups/wg/apa/
# 3                  https://www.w3.org/groups/wg/aria/
# 4                 https://www.w3.org/groups/wg/audio/
# 5   https://www.w3.org/groups/wg/browser-tools-tes...
# 6                   https://www.w3.org/groups/wg/css/
# 7                    https://www.w3.org/groups/wg/dx/
# 8                   https://www.w3.org/groups/wg/did/
# 9                   https://www.w3.org/groups/wg/das/
# 10  https://www.w3.org/groups/wg/distributed-tracing/
# 11                https://www.w3.org/groups/wg/fedid/
# 12                  https://www.w3.org/groups/wg/gpu/
# 13               https://www.w3.org/groups/wg/htmlwg/
# 14        https://www.w3.org/groups/wg/immersive-web/
# 15            https://www.w3.org/groups/wg/i18n-core/
# 16              https://www.w3.org/groups/wg/json-ld/
# 17                 https://www.w3.org/groups/wg/math/
# 18                https://www.w3.org/groups/wg/media/
# 19             https://www.w3.org/groups/wg/miniapps/
# 20       https://www.w3.org/groups/wg/pointer-events/
# 21                  https://www.w3.org/groups/wg/png/
# 22                   https://www.w3.org/groups/wg/pm/
# 23                  https://www.w3.org/groups/wg/rch/
# 24             https://www.w3.org/groups/wg/rdf-star/
# 25         https://www.w3.org/groups/wg/secondscreen/
# 26      https://www.w3.org/groups/wg/service-workers/
# 27                  https://www.w3.org/groups/wg/sdw/
# 28                  https://www.w3.org/groups/wg/svg/
# 29           https://www.w3.org/groups/wg/timed-text/
# 30                   https://www.w3.org/groups/wg/vc/
# 31            https://www.w3.org/groups/wg/webappsec/
# 32              https://www.w3.org/groups/wg/webapps/
# 33             https://www.w3.org/groups/wg/webauthn/
# 34           https://www.w3.org/groups/wg/webediting/
# 35             https://www.w3.org/groups/wg/webfonts/
# 36   https://www.w3.org/groups/wg/webmachinelearning/
# 37                  https://www.w3.org/groups/wg/wot/
# 38             https://www.w3.org/groups/wg/payments/
# 39              https://www.w3.org/groups/wg/webperf/
# 40               https://www.w3.org/groups/wg/webrtc/
# 41                 https://www.w3.org/groups/wg/wasm/
# 42         https://www.w3.org/groups/wg/webtransport/
#
#                                           description                    tag
# 0   The mission of the Accessibility Education and...                   eowg
# 1   The mission of the Accessibility Guidelines Wo...                     ag
# 2   The mission of the Accessible Platform Archite...                    apa
# 3   The mission of the Accessible Rich Internet Ap...                   aria
# 4   The mission of the Audio Working Group is to a...                  audio
# 5   The mission of the Browser Testing and Tools W...  browser-tools-testing
# 6   The mission of the group is to develop and mai...                    css
# 7   The mission of the Dataset Exchange WG is to:\...                     dx
# 8   The mission of the Decentralized Identifier Wo...                    did
# 9   The mission of the Devices and Sensors Working...                    das
# 10  The mission of the Distributed Tracing is to d...    distributed-tracing
# 11  The mission of the Federated Identity Working ...                  fedid
# 12  The mission of the GPU for the Web Working Gro...                    gpu
# 13  The mission of the HTML Working Group is to gi...                 htmlwg
# 14  The mission of the Immersive Web Working Group...          immersive-web
# 15  The mission of the Internationalization Workin...              i18n-core
# 16  The mission of the JSON-LD Working Group is to...                json-ld
# 17  The mission of the Math Working Group is to pr...                   math
# 18  The mission of the Media Working Group is to d...                  media
# 19  The mission of the MiniApps Working Group is t...               miniapps
# 20  The mission of the Pointer Events Working Grou...         pointer-events
# 21  The mission of the PNG Working Group is to mai...                    png
# 22  The mission of the Publishing Maintenance Work...                     pm
# 23  The mission of the RDF Dataset Canonicalizatio...                    rch
# 24  The mission of the RDF-star Working Group is t...               rdf-star
# 25  The mission of the Second Screen Working Group...           secondscreen
# 26  The mission of the Service Workers Working Gro...        service-workers
# 27  The mission of the Spatial Data on the Web Wor...                    sdw
# 28  The mission of the Scalable Vector Graphics (S...                    svg
# 29  The mission of the Timed Text Working Group is...             timed-text
# 30  The mission of the Verifiable Credentials Work...                     vc
# 31  The mission of the Web Application Security Wo...              webappsec
# 32  The mission of the Web Applications Working Gr...                webapps
# 33  The mission of the Web Authentication Working ...               webauthn
# 34  The mission of the Web Editing Working Group i...             webediting
# 35  The mission of the Web Fonts Working Group is ...               webfonts
# 36  The mission of the Web Machine Learning Workin...     webmachinelearning
# 37  The Web of Things seeks to counter the fragmen...                    wot
# 38  The mission of the Web Payments Working Group ...               payments
# 39  The mission of the Web Performance Working Gro...                webperf
# 40  The mission of the Web Real-Time Communication...                 webrtc
# 41  The mission of the WebAssembly Working Group i...                   wasm
# 42  The mission of the WebTransport Working Group ...           webtransport
