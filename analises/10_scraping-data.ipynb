# %% [markdown]
# # Scraping W3C working group data

# %% [markdown]
# This notebooks scraps the data from the W3C website.

# %%
import pandas as pd
import requests
from selenium.webdriver import Firefox
from time import sleep
from bs4 import BeautifulSoup
import re
from glob import glob

# %% [markdown]
# ## Functions

# %%
def find_class(soup, class_attr):
    """
    Given a Beautiful Soup object `soup`, return its first element
    whose 'class' attribute is `class_attr` (str) as a Beautiful soup
    object.
    """
    
    return soup.find(attrs={'class':class_attr})


def get_class_text(soup, class_attr, strip=True):
    """
    Return the text inside the first element  in `soup` 
    (Beautiful Soup object) whose 'class' attribute 
    is `class_attr`. If `strip` is True, remove trailing 
    empty spaces.
    """
    element = find_class(soup, class_attr)
    if type(element) == type(None):
        return None
    
    text = element.text
    if strip == True:
        text = text.strip()
    
    return text


def find_all_class(soup, class_attr):
    """
    Given a Beautiful Soup object `soup`, return all its elements
    whose 'class' attribute is `class_attr` (str) as a list of 
    Beautiful soup objects.    
    """
    elements = soup.find_all(attrs={'class': class_attr})

    return elements


def source_to_class_elements(source, class_attr):
    """
    Given a HTML page source code `source` (str), return all 
    its elements whose 'class' attribute is `class_attr` (str) 
    as a list of Beautiful soup objects.    
    """
    
    soup = BeautifulSoup(source, features='lxml')
    elements = find_all_class(soup, class_attr)
    
    return elements

# %%
def scrap_group_card(group_card):
    """
    Given an HTML div containing info about a W3C working group
    (BeautifulSoup element Tag), return a dict with the group's
    name, url and description.
    """
    data = dict()
    
    data['name'] = group_card.find('h2').text.strip()
    data['url'] = root + group_card.find('a').attrs['href']
    data['description'] = group_card.find('p').text
    
    return data

# %%
def trim_whitespaces(string):
    """
    Remove excessive whitespace from string.
    """
    return ' '.join(string.strip().split())

# %%
def get_page_source(url):
    """
    Use Selenium to download the source of the webpage 
    at `url` (str). Return it as a str.
    """
    
    # Get page source:
    driver = Firefox()
    driver.get(url)
    sleep(5)
    source = driver.page_source
    
    driver.close()
    driver.quit()

    return source

# %%
def scrap_member(member_card, root, section=None):
    """
    Get data about an WG member from the HTML element 
    (Beautifulsoup element Tag), pass it to a dict.
    """
    # Initialize data about member:
    data = dict()
    data['name']     = None
    data['org_name'] = None
    data['org_url']  = None 
    data['email']    = None
    data['github']   = None
    data['picture']  = None
    data['role']     = section
    
    # Get name:
    data['name'] = trim_whitespaces(member_card.find('h3').text)
    
    # Get organization name and URL:
    org = member_card.find('p')
    data['org_name'] = trim_whitespaces(org.text)
    org_link = org.find('a')
    if org_link != None:
        data['org_url']  = root + org_link.attrs['href']
    
    # Get email and github:
    infos = find_all_class(member_card, 'with-icon--before')
    for info in infos:
        link = info.attrs['href']
        if link.find('mailto') != -1:
            data['email'] = link.split(':')[1]
        elif link.find('github') != -1:
            data['github'] = link

    # Get picture URL:
    data['picture'] = root + find_class(member_card, 'avatar').find('img').attrs['src']

    return data

# %%
def get_section_id(section):
    """
    Look for 'id' attribute in a 'h2' header, and return it.
    """
    header = section.find('h2')
    if header == None: 
        return None
    return header.attrs['id']

# %%
def scrap_wg_members(url, root, driver):
    """
    Scrap data about W3C WG members from the group's page.
    NOTE: You must perform the login in the `driver` browser
    before calling this function, in order for all information
    to be available.
    
    Parameters
    ----------
    url : str
        Address of the page.
    root : str
        website root URL.
    driver : selenium WebDriver
        Browser used in the scraping. It must have been 
        initialized and logged in already.

    Returns
    -------
    members_info : list of dict
        Data about the members.
    """
    
    # Get page source:
    driver.get(url)
    src = driver.page_source
    
    # Get participants categories:
    #section_ids = ['chairs', 'staff', 'participants']
    soup = BeautifulSoup(src)
    category_sections = find_all_class(soup, 'component--text')
    section_ids = [get_section_id(c) for c in category_sections]
    assert section_ids[0] == None
    
    # Loop over categories of members:
    members_info = []
    for section, section_id in zip(category_sections[1:], section_ids[1:]):
        assert section.find('h2').attrs['id'] == section_id
        # Scrap members infos for section (member category):
        member_cards = find_all_class(section, 'card--user')
        # Add to WG members list:
        members_info += [scrap_member(m, root, section_id) for m in member_cards]

    return members_info

# %%
def remove_accents(string, i=0):
    """
    Input: string
    
    Returns the same string, but without all portuguese-valid accents.
    """
    
    # Missing values case:
    if type(string) == type(np.NaN):
        return string
    
    accent_list = [('Ç','C'),('Ã','A'),('Á','A'),('À','A'),('Â','A'),('É','E'),('Ê','E'),('Í','I'),('Õ','O'),('Ó','O'),
                   ('Ô','O'),('Ú','U'),('Ü','U'),('ç','c'),('ã','a'),('á','a'),('à','a'),('â','a'),('é','e'),('ê','e'),
                   ('í','i'),('õ','o'),('ó','o'),('ô','o'),('ú','u'),('ü','u'),('È','E'),('Ö','O'),('Ñ','N'),('è','e'),
                   ('ö','o'),('ñ','n'),('Ë','E'),('ë','e'),('Ä','A'),('ä','a')]
    if i >= len(accent_list):
        return string
    else:
        string = string.replace(*accent_list[i])
        return remove_accents(string, i + 1)


def text2tag(text):
    """
    Simplify `text` to use it as part os filenames and so on
    (lowercase it, remove accents and spaces).
    """

    # Remove duplicated spaces:
    text = ' '.join(text.split())
    # Transform to tag:
    tag  = re.sub('[\.,;!:\(\)/]', '', remove_accents(text).lower().replace(' ', '_'))
    return tag

# %%
def split_name_email(value):
    """
    Split name from email in the format:
        John Smith ( john@email.com )
    Returns the name and the email.
    """
    parts = [trim_whitespaces(s) for s in value.split(')')[0].split('(')]
    return parts[0], parts[1]

# %%
def scrap_org_info(url, root, driver):
    """
    Scrap W3C member organization from W3C website URL.
    You must be logged in to access the webpages.

    Parameters
    ----------
    url : str
        Address of the organization's page.
    root : str
        website root URL.
    driver : selenium WebDriver
        Browser used in the scraping. It must have been 
        initialized and logged in already.

    Returns
    -------
    org_data : dict
        Data about the organization.
    """
    
    # GET HTML:
    driver.get(url)
    src = driver.page_source
    soup = BeautifulSoup(src)
    
    # Initialize data:
    org_data = dict()
    # Org. name:
    org_data['name'] = trim_whitespaces(soup.find('h1').text)
    # Org logo:
    details = find_class(soup, 'details')
    img = details.find('img')
    if img == None:
        org_data['logo'] = None
    else:
        org_data['logo'] = root + img.attrs['src']
    # Testimonial:
    test_element = details.find(attrs={'id':'en-testimonial'})
    if test_element is None:
        org_data['testimonial'] = None
    else:
        org_data['testimonial'] = test_element.text
    # Other info (from table):
    grid = find_class(details, 'grid')
    labels = [text2tag(trim_whitespaces(r.text)) for r in grid.find_all('dt')]
    values = [trim_whitespaces(r.text) for r in grid.find_all('dd')]
    raw_details = dict(zip(labels, values))
    
    # Parse representative's name and email:
    for role in ['ac_rep', 'alternate_ac_rep']:
        if role in labels:
            if trim_whitespaces(raw_details[role]) == 'None':
                name, email = None, None
            else:
                name, email = split_name_email(raw_details[role])
            raw_details[role + '_email'] = email
            raw_details[role] = name
            
    # Combine details with name and logo:
    org_data.update(raw_details)

    return org_data

# %% [markdown]
# ## Scraping list of working groups (WGs)

# %%
# GET W3C WG page:
url  = 'https://www.w3.org/groups/wg/'
root = 'https://www.w3.org'
response = requests.get(url)
soup = BeautifulSoup(response.text)

# %%
# Extract data:
group_cards = find_all_class(soup, 'card--group')
group_data = [scrap_group_card(g) for g in group_cards]
group_df = pd.DataFrame(group_data)

# %%
# Add identifier:
group_df['tag'] = group_df['url'].str.split('/').str.slice(-2,-1).str.join('')
assert group_df['tag'].nunique() == len(group_df)

# %%
# Save to file:
#group_df.to_csv('../dados/brutos/w3c_wg_2024-07-04.csv', index=False)

# %% [markdown]
# ## Scraping members of WGs

# %%
# Load list of WGs:
root = 'https://www.w3.org'
group_df = pd.read_csv('../dados/brutos/w3c_wg_2024-07-04.csv')

# Hard-coded URL paths:
members_path = 'participants/'

# Start browser:
driver = Firefox()
driver.get(root)

# %% [markdown]
# It is necessary to authenticate in the browser above to scrap information.

# %%
# Loop over WGs:
for i in range(len(group_df)):
#for i in range(26, 27):

    # Get page URL of the WG:
    group = group_df.iloc[i]
    print(i, group['name'])
    url = group['url'] + members_path
    
    # Scrap members:
    members_info = scrap_wg_members(url, root, driver)
    # Add group ID:
    members_df = pd.DataFrame(members_info)
    members_df['group_tag'] = group['tag']

    # Save to file:
    members_df.to_csv('../dados/brutos/w3c-wg-members_{}_2024-07-04.csv'.format(group['tag']), index=False)
    
    sleep(5)
# Out:
# 26 Service Workers Working Group

# %%
# Groups with no chairs:
bug_groups = ['https://www.w3.org/groups/wg/service-workers/participants/']

# %% [markdown]
# ## Scraping data from organizations

# %%
# Load all organizations:
all_orgs_df = pd.read_csv('../data/raw/api/w3c_organizations_list_2024-07-06.csv')
all_org_list = list('https://www.w3.org/organizations/' + all_orgs_df['href'].str.split('/').str.slice(-1).str.join(''))

# %%
# Load organizations in WGs list:
filenames = glob('../dados/brutos/w3c-wg-members_*.csv')
raw_members_df = pd.concat([pd.read_csv(f) for f in filenames])
org_list = raw_members_df['org_url'].dropna().unique()

# %%
# Start browser:
root = 'https://www.w3.org'
driver = Firefox()
driver.get(root)
# Out:
# The geckodriver version (0.33.0) detected in PATH at /home/hxavier/system/bin/geckodriver might not be compatible with the detected firefox version (127.0.2); currently, geckodriver 0.34.0 is recommended for firefox 127.*, so it is advised to delete the driver in PATH and retry

# %% [markdown]
# It is necessary to authenticate in the browser above to scrap information.

# %%
# Over all organizations:
org_data = []
for i in range(len(all_org_list)):
    print(i, all_org_list[i])
    data = scrap_org_info(all_org_list[i], root, driver)
    data['url'] = all_org_list[i]
    org_data.append(data)

    sleep(2)
# Out:
# 0 https://www.w3.org/organizations/1001
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 4
#       2 for i in range(len(all_org_list)):
#       3     print(i, all_org_list[i])
# ----> 4     data = scrap_org_info(all_org_list[i], root, driver)
#       5     data['url'] = all_org_list[i]
#       6     org_data.append(data)
#
# Cell In[11], line 33, in scrap_org_info(url, root, driver)
#      31 # Org logo:
#      32 details = find_class(soup, 'details')
# ---> 33 img = details.find('img')
#      34 if img == None:
#      35     org_data['logo'] = None
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# Over WG organizations:
org_data = []
for i in range(len(org_list)):
    print(i, org_list[i])
    data = scrap_org_info(org_list[i], root, driver)
    data['url'] = org_list[i]
    org_data.append(data)

    sleep(2)
# Out:
# 2 https://www.w3.org/organizations/1066/
# 3 https://www.w3.org/organizations/112585/
# 4 https://www.w3.org/organizations/62028/
# 5 https://www.w3.org/organizations/1202/
# 6 https://www.w3.org/organizations/79706/
# 7 https://www.w3.org/organizations/131353/
# 8 https://www.w3.org/organizations/116778/
# 9 https://www.w3.org/organizations/46877/
# 10 https://www.w3.org/organizations/133378/
# 11 https://www.w3.org/organizations/1057/
# 12 https://www.w3.org/organizations/1219/
# 13 https://www.w3.org/organizations/119171/
# 14 https://www.w3.org/organizations/140732/
# 15 https://www.w3.org/organizations/61566/
# 16 https://www.w3.org/organizations/48024/
# 17 https://www.w3.org/organizations/69906/
# 18 https://www.w3.org/organizations/143173/
# 19 https://www.w3.org/organizations/93515/
# 20 https://www.w3.org/organizations/43576/
# 21 https://www.w3.org/organizations/141535/
# 22 https://www.w3.org/organizations/1092/
# 23 https://www.w3.org/organizations/114837/
# 24 https://www.w3.org/organizations/116845/
# 25 https://www.w3.org/organizations/130635/
# 26 https://www.w3.org/organizations/1086/
# 27 https://www.w3.org/organizations/74902/
# 28 https://www.w3.org/organizations/95986/
# 29 https://www.w3.org/organizations/52052/
# 30 https://www.w3.org/organizations/129181/
# 31 https://www.w3.org/organizations/137962/
# 32 https://www.w3.org/organizations/53821/
# 33 https://www.w3.org/organizations/142760/
# 34 https://www.w3.org/organizations/70179/
# 35 https://www.w3.org/organizations/139630/
# 36 https://www.w3.org/organizations/35429/
# 37 https://www.w3.org/organizations/117162/
# 38 https://www.w3.org/organizations/42701/
# 39 https://www.w3.org/organizations/126165/
# 40 https://www.w3.org/organizations/36700/
# 41 https://www.w3.org/organizations/116443/
# 42 https://www.w3.org/organizations/33823/
# 43 https://www.w3.org/organizations/139773/
# 44 https://www.w3.org/organizations/126338/
# 45 https://www.w3.org/organizations/132520/
# 46 https://www.w3.org/organizations/39619/
# 47 https://www.w3.org/organizations/28169/
# 48 https://www.w3.org/organizations/10911/
# 49 https://www.w3.org/organizations/135578/
# 50 https://www.w3.org/organizations/34345/
# 51 https://www.w3.org/organizations/121085/
# 52 https://www.w3.org/organizations/129039/
# 53 https://www.w3.org/organizations/9829/
# 54 https://www.w3.org/organizations/151359/
# 55 https://www.w3.org/organizations/131436/
# 56 https://www.w3.org/organizations/139511/
# 57 https://www.w3.org/organizations/108617/
# 58 https://www.w3.org/organizations/43103/
# 59 https://www.w3.org/organizations/68381/
# 60 https://www.w3.org/organizations/66654/
# 61 https://www.w3.org/organizations/10894/
# 62 https://www.w3.org/organizations/1088/
# 63 https://www.w3.org/organizations/47545/
# 64 https://www.w3.org/organizations/66234/
# 65 https://www.w3.org/organizations/36231/
# 66 https://www.w3.org/organizations/68998/
# 67 https://www.w3.org/organizations/1210/
# 68 https://www.w3.org/organizations/43420/
# 69 https://www.w3.org/organizations/38525/
# 70 https://www.w3.org/organizations/97591/
# 71 https://www.w3.org/organizations/76927/
# 72 https://www.w3.org/organizations/83781/
# 73 https://www.w3.org/organizations/40030/
# 74 https://www.w3.org/organizations/75851/
# 75 https://www.w3.org/organizations/39350/
# 76 https://www.w3.org/organizations/46378/
# 77 https://www.w3.org/organizations/97658/
# 78 https://www.w3.org/organizations/86485/
# 79 https://www.w3.org/organizations/132463/
# 80 https://www.w3.org/organizations/102416/
# 81 https://www.w3.org/organizations/104014/
# 82 https://www.w3.org/organizations/102258/
# 83 https://www.w3.org/organizations/33654/
# 84 https://www.w3.org/organizations/106670/
# 85 https://www.w3.org/organizations/68737/
# 86 https://www.w3.org/organizations/82711/
# 87 https://www.w3.org/organizations/134143/
# 88 https://www.w3.org/organizations/84446/
# 89 https://www.w3.org/organizations/150912/
# 90 https://www.w3.org/organizations/68687/
# 91 https://www.w3.org/organizations/92370/
# 92 https://www.w3.org/organizations/137898/
# 93 https://www.w3.org/organizations/75253/
# 94 https://www.w3.org/organizations/143583/
# 95 https://www.w3.org/organizations/39493/
# 96 https://www.w3.org/organizations/53817/
# 97 https://www.w3.org/organizations/68295/
# 98 https://www.w3.org/organizations/7552/
# 99 https://www.w3.org/organizations/122067/
# 100 https://www.w3.org/organizations/35668/
# 101 https://www.w3.org/organizations/1163/
# 102 https://www.w3.org/organizations/38621/
# 103 https://www.w3.org/organizations/37224/
# 104 https://www.w3.org/organizations/1051/
# 105 https://www.w3.org/organizations/98318/
# 106 https://www.w3.org/organizations/75848/
# 107 https://www.w3.org/organizations/105655/
# 108 https://www.w3.org/organizations/29696/
# 109 https://www.w3.org/organizations/69854/
# 110 https://www.w3.org/organizations/125874/
# 111 https://www.w3.org/organizations/51608/
# 112 https://www.w3.org/organizations/1120/
# 113 https://www.w3.org/organizations/1117/
# 114 https://www.w3.org/organizations/126211/
# 115 https://www.w3.org/organizations/93614/
# 116 https://www.w3.org/organizations/45096/
# 117 https://www.w3.org/organizations/26556/
# 118 https://www.w3.org/organizations/66769/
# 119 https://www.w3.org/organizations/114165/
# 120 https://www.w3.org/organizations/12480/
# 121 https://www.w3.org/organizations/1015/
# 122 https://www.w3.org/organizations/141557/
# 123 https://www.w3.org/organizations/135442/
# 124 https://www.w3.org/organizations/129310/
# 125 https://www.w3.org/organizations/16188/
# 126 https://www.w3.org/organizations/56271/
# 127 https://www.w3.org/organizations/89490/
# 128 https://www.w3.org/organizations/111458/
# 129 https://www.w3.org/organizations/72177/
# 130 https://www.w3.org/organizations/114633/
# 131 https://www.w3.org/organizations/9832/
# 132 https://www.w3.org/organizations/59545/
# 133 https://www.w3.org/organizations/16322/
# 134 https://www.w3.org/organizations/128554/
# 135 https://www.w3.org/organizations/112208/
# 136 https://www.w3.org/organizations/125364/
# 137 https://www.w3.org/organizations/133121/
# 138 https://www.w3.org/organizations/146627/
# 139 https://www.w3.org/organizations/51381/
# 140 https://www.w3.org/organizations/129545/
# 141 https://www.w3.org/organizations/146430/
# 142 https://www.w3.org/organizations/139480/
# 143 https://www.w3.org/organizations/116404/
# 144 https://www.w3.org/organizations/135571/
# 145 https://www.w3.org/organizations/138132/
# 146 https://www.w3.org/organizations/82274/
# 147 https://www.w3.org/organizations/65543/
# 148 https://www.w3.org/organizations/104534/
# 149 https://www.w3.org/organizations/112788/
# 150 https://www.w3.org/organizations/108522/
# 151 https://www.w3.org/organizations/110197/
# 152 https://www.w3.org/organizations/142936/
# 153 https://www.w3.org/organizations/127610/
# 154 https://www.w3.org/organizations/109668/
# 155 https://www.w3.org/organizations/117717/
# 156 https://www.w3.org/organizations/139760/
# 157 https://www.w3.org/organizations/46141/
# 158 https://www.w3.org/organizations/130494/
# 159 https://www.w3.org/organizations/140769/
# 160 https://www.w3.org/organizations/1060/
# 161 https://www.w3.org/organizations/151757/
# 162 https://www.w3.org/organizations/109588/
# 163 https://www.w3.org/organizations/147517/
# 164 https://www.w3.org/organizations/53750/
# 165 https://www.w3.org/organizations/152991/
# 166 https://www.w3.org/organizations/106987/
# 167 https://www.w3.org/organizations/7211/
# 168 https://www.w3.org/organizations/99362/
# 169 https://www.w3.org/organizations/72139/
# 170 https://www.w3.org/organizations/71673/
# 171 https://www.w3.org/organizations/96831/
# 172 https://www.w3.org/organizations/9826/
# 173 https://www.w3.org/organizations/9961/
# 174 https://www.w3.org/organizations/117787/
# 175 https://www.w3.org/organizations/49669/
# 176 https://www.w3.org/organizations/126911/
# 177 https://www.w3.org/organizations/126627/
# 178 https://www.w3.org/organizations/130350/
# 179 https://www.w3.org/organizations/103247/
# 180 https://www.w3.org/organizations/12390/
# 181 https://www.w3.org/organizations/141809/
# 182 https://www.w3.org/organizations/98847/
# 183 https://www.w3.org/organizations/1142/
# 184 https://www.w3.org/organizations/1183/
# 185 https://www.w3.org/organizations/146904/
# 186 https://www.w3.org/organizations/151838/
# 187 https://www.w3.org/organizations/56103/
# 188 https://www.w3.org/organizations/91879/
# 189 https://www.w3.org/organizations/51826/
# 190 https://www.w3.org/organizations/140697/
# 191 https://www.w3.org/organizations/1108/
# 192 https://www.w3.org/organizations/1027/
# 193 https://www.w3.org/organizations/136166/
# 194 https://www.w3.org/organizations/116510/
# 195 https://www.w3.org/organizations/37883/
# 196 https://www.w3.org/organizations/52054/
# 197 https://www.w3.org/organizations/110879/
# 198 https://www.w3.org/organizations/110285/
# 199 https://www.w3.org/organizations/97636/
# 200 https://www.w3.org/organizations/101246/
# 201 https://www.w3.org/organizations/29822/
# 202 https://www.w3.org/organizations/144055/
# 203 https://www.w3.org/organizations/118052/
# 204 https://www.w3.org/organizations/127220/
# 205 https://www.w3.org/organizations/62643/
# 206 https://www.w3.org/organizations/43051/
# 207 https://www.w3.org/organizations/76452/
# 208 https://www.w3.org/organizations/139249/
# 209 https://www.w3.org/organizations/54991/
# 210 https://www.w3.org/organizations/9833/
# 211 https://www.w3.org/organizations/47581/
# 212 https://www.w3.org/organizations/140493/
# 213 https://www.w3.org/organizations/88224/
# 214 https://www.w3.org/organizations/48275/
# 215 https://www.w3.org/organizations/49753/
# 216 https://www.w3.org/organizations/147028/
# 217 https://www.w3.org/organizations/155386/
# 218 https://www.w3.org/organizations/9848/
# 219 https://www.w3.org/organizations/125161/
# 220 https://www.w3.org/organizations/39381/
# 221 https://www.w3.org/organizations/75919/
# 222 https://www.w3.org/organizations/37846/
# 223 https://www.w3.org/organizations/80863/
# 224 https://www.w3.org/organizations/79293/
# 225 https://www.w3.org/organizations/111912/
# 226 https://www.w3.org/organizations/26550/
# 227 https://www.w3.org/organizations/96789/

# %%
org_df = pd.DataFrame(org_data)

# %%
# Save data:
#org_df.to_csv('../dados/brutos/w3c_organizations_2024-07-04.csv', index=False)
